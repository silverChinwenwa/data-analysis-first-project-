# %%
print("jupyter is working")
# Out:
# jupyter is working

# %%
import pandas as pd

df1=pd.read_csv("netflix_titles.csv")
df2=pd.read_csv("OnlineRetail.csv", encoding="latin1")

df1.head()
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df1.head()
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df1.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# The director, cast, date_added, country coulumn contains missing values

# %%
df2.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# The description and CustomerID columns have missing data

# %%
df1=df1.dropna()

# %%
df2=df2.dropna()

# %%
df1=df1.drop_duplicates()

# %%
df2=df2.drop_duplicates()

# %%
df1.columns=df1.columns.str.lower().str.replace("","_")

# %%
df2.columns=df2.columns.str.lower().str.replace("","_")

# %%
df1.columns
# Out:
# Index(['_s_h_o_w___i_d_', '_t_y_p_e_', '_t_i_t_l_e_', '_d_i_r_e_c_t_o_r_',
#        '_c_a_s_t_', '_c_o_u_n_t_r_y_', '_d_a_t_e___a_d_d_e_d_',
#        '_r_e_l_e_a_s_e___y_e_a_r_', '_r_a_t_i_n_g_', '_d_u_r_a_t_i_o_n_',
#        '_l_i_s_t_e_d___i_n_', '_d_e_s_c_r_i_p_t_i_o_n_'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['_i_n_v_o_i_c_e_n_o_', '_s_t_o_c_k_c_o_d_e_', '_d_e_s_c_r_i_p_t_i_o_n_',
#        '_q_u_a_n_t_i_t_y_', '_i_n_v_o_i_c_e_d_a_t_e_', '_u_n_i_t_p_r_i_c_e_',
#        '_c_u_s_t_o_m_e_r_i_d_', '_c_o_u_n_t_r_y_'],
#       dtype='object')

# %% [markdown]
# Key variables in Dataset 1 include (title, country, data_added) and for Dataset 2 include (InvoiceNo. CustomerID, Quantity, UnitPrice)

# %%
df1.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df2.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# The datasets contain a mix of numerical and categorical variables. Numerical variaable like (date_added,InvoiceDate, UnitPrice, Quantity) and categorical variable like(Description, Country, title, director)

# %%
df2.shape
# Out:
# (541909, 8)

# %%
df1.shape
# Out:
# (8807, 12)

# %% [markdown]
# Dataset 1 contains 8807 rows and 12 columns
# Dataset 2 contains 541909 rows and 8 columns
# This means the dataset is large.

# %%
df1.describe()
# Out:
#        _r_e_l_e_a_s_e___y_e_a_r_
# count                5332.000000
# mean                 2012.742123
# std                     9.625831
# min                  1942.000000
# 25%                  2011.000000
# 50%                  2016.000000
# 75%                  2018.000000
# max                  2021.000000

# %%
df2.describe()
# Out:
#        _q_u_a_n_t_i_t_y_  _u_n_i_t_p_r_i_c_e_  _c_u_s_t_o_m_e_r_i_d_
# count      401604.000000        401604.000000          401604.000000
# mean           12.183273             3.474064           15281.160818
# std           250.283037            69.764035            1714.006089
# min        -80995.000000             0.000000           12346.000000
# 25%             2.000000             1.250000           13939.000000
# 50%             5.000000             1.950000           15145.000000
# 75%            12.000000             3.750000           16784.000000
# max         80995.000000         38970.000000           18287.000000

# %% [markdown]
# A negative value was observed in the dataset 2. Since the variable represents quantity that cannot logically be negative so it is an anomaly.

# %%
df1["_d_a_t_e___a_d_d_e_d_"].value_counts().plot(kind='bar')
plt.show()

# %%
df2['_c_u_s_t_o_m_e_r_i_d_'].value_counts().plot(kind='bar')
plt.show()

# %%
df1.to_csv("cleaned_netflix_titles.csv", index=False)

# %%
df2.to_csv("cleaned_OnlineRetail.csv", index=False)

# %%
import matplotlib.pyplot as plt
